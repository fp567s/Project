# %%
"""
Run object detection with VOC classes.

This is just a minor modification of code from
https://github.com/rykov8/ssd_keras
"""

from keras.applications.imagenet_utils import preprocess_input
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import imread
import sys

from ssd import SSD300
from ssd_utils import BBoxUtility
import os
from os.path import basename

# %%
def create_overlay(img, results,voc_classes , plt_fname):
    plt.clf()
    # Parse the outputs.
    det_label = results[:, 0]
    det_conf = results[:, 1]
    det_xmin = results[:, 2]
    det_ymin = results[:, 3]
    det_xmax = results[:, 4]
    det_ymax = results[:, 5]

    # Get detections with confidence higher than 0.6.
    top_indices = [i for i, conf in enumerate(det_conf) if conf >= 0.6]

    top_conf = det_conf[top_indices]
    top_label_indices = det_label[top_indices].tolist()
    top_xmin = det_xmin[top_indices]
    top_ymin = det_ymin[top_indices]
    top_xmax = det_xmax[top_indices]
    top_ymax = det_ymax[top_indices]
    colors = plt.cm.hsv(np.linspace(0, 1, 21)).tolist()

    plt.imshow(img / 255.)
    currentAxis = plt.gca()
    currentAxis.axis('off')

    for i in range(top_conf.shape[0]):
        xmin = int(round(top_xmin[i] * img.shape[1]))
        ymin = int(round(top_ymin[i] * img.shape[0]))
        xmax = int(round(top_xmax[i] * img.shape[1]))
        ymax = int(round(top_ymax[i] * img.shape[0]))
        score = top_conf[i]
        label = int(top_label_indices[i])
        label_name = voc_classes[label - 1]
        display_txt = '{:0.2f}, {}'.format(score, label_name)
        coords = (xmin, ymin), xmax - xmin + 1, ymax - ymin + 1
        color = colors[label]
        currentAxis.add_patch(plt.Rectangle(*coords,
                                            fill=False,
                                            edgecolor=color,
                                            linewidth=2))
        currentAxis.text(xmin, ymin, display_txt,
                         bbox={'facecolor': color, 'alpha': 0.5})
    plt.savefig(plt_fname)
    print("save "+plt_fname)

if __name__ == "__main__":
    import glob
    imagesList = glob.glob("images/*.jpg")

    # Load the model
    voc_classes = ['Aeroplane', 'Bicycle', 'Bird', 'Boat', 'Bottle',
                   'Bus', 'Car', 'Cat', 'Chair', 'Cow', 'Diningtable',
                   'Dog', 'Horse', 'Motorbike', 'Person', 'Pottedplant',
                   'Sheep', 'Sofa', 'Train', 'Tvmonitor']
    NUM_CLASSES = len(voc_classes) + 1
    input_shape = (300, 300, 3)
    model = SSD300(input_shape, num_classes=NUM_CLASSES)
    model.load_weights('weights_SSD300.hdf5', by_name=True)
    bbox_util = BBoxUtility(NUM_CLASSES)

    # Load the inputs
    inputs = []
    images = []
    for img_path in imagesList:
        print("process " + img_path)
        img = image.load_img(img_path, target_size=(300, 300))
        img = image.img_to_array(img)
        images.append(imread(img_path))
        inputs.append(img.copy())
    # 前置處理
    print("前置處理...")
    inputs = preprocess_input(np.array(inputs))

    # 預測
    print("預測...")
    preds = model.predict(inputs, batch_size=1, verbose=1)
    # 取得預測結果
    results = bbox_util.detection_out(preds)
    print("results[0]=")
    print(results[0][0][1])

    # create folder if not exist
    output_directory="results"
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    # proces images
    for i, img in enumerate(images):
        # 產生有框的 output files
        create_overlay(img, results[i], voc_classes,
           output_directory+"/{}.png".format(basename(os.path.splitext(imagesList[i])[0])))
    # Garbage collection, to prevent from TensorFlow error
    import gc
    gc.collect()
# Out:
# process images\05-08-07_1919.jpg.jpg
# process images\1483977247_51bb24b461.jpg.jpg
# process images\2069648819_b2a091fc77.jpg.jpg
# process images\2153642330_881e250a88.jpg.jpg
# process images\2153642430_c8659ae417.jpg.jpg
# process images\2308322303_01b6ffbc15.jpg.jpg
# process images\2405671059_9076f89469.jpg.jpg
# process images\2407970586_72405c8488.jpg.jpg
# process images\2612657927_969e9bb275.jpg.jpg
# process images\2617083134_d02d5103aa.jpg.jpg
# C:\Users\user\Anaconda3\envs\tensorflow-CPU\lib\site-packages\ipykernel_launcher.py:68: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# process images\2688754749_35ab0c3774.jpg.jpg
# process images\269287644_c0262e0fc8.jpg
# process images\270199524_a816eac80b.jpg
# process images\278759049_ebfd22a71a.jpg
# process images\291174019_b4821c2397.jpg
# process images\300980715_6026e616f1.jpg
# process images\303058433_cbb6f763a3.jpg
# process images\306796477_cd48f3064c.jpg
# process images\314275828_94a8d70fec.jpg
# process images\329074102_8b41060baa.jpg
# process images\330211453_f55e845b84.jpg
# process images\447004743_fe921f2cdc.jpg
# process images\448871457_2b2502c248.jpg
# process images\450063221_09be2f43d1.jpg
# process images\450186182_1a8cef631d.jpg
# process images\457103202_ee723558ed.jpg
# process images\464044679_b6fbfe1535.jpg
# process images\473624228_11a6bc4203.jpg
# process images\bear and dog.jpg
# process images\bird01.jpg
# process images\bottega-e-furgone.jpg.jpg
# process images\boys.jpg
# process images\Cappuccino-2.jpg
# process images\Cappuccino-3.jpg
# process images\Cappuccino-4.jpg
# process images\car_cat.jpg
# process images\car_cat2.jpg
# process images\cat-2.jpg
# process images\cat-3.jpg
# process images\cat-4.jpg
# process images\cat-5.jpg
# process images\cat-6.jpg
# process images\cat.jpg
# process images\elephant2.jpg
# process images\fish-bike.jpg
# process images\Foto+Serigrafia+Furgoneta+Valencia+Inges+Kunesa.jpg.jpg
# process images\furgon01g.jpg.jpg
# process images\furgon_restos_erika_Ortiz.jpg.jpg
# process images\Imagen+034.jpg.jpg
# process images\input.jpg
# process images\JINJIN.jpg
# process images\opel-movano-furgon-lb.jpg.jpg
# process images\tiger-2.jpg
# process images\tiger-3.jpg
# process images\tiger.jpg
# process images\u%20furgone%201.JPG.jpg
# 前置處理...
# 預測...
# 56/56 [==============================] - 64s 1s/step
# results[0]=
# 0.8696705102920532
# save results/05-08-07_1919.jpg.png
# save results/1483977247_51bb24b461.jpg.png
# save results/2069648819_b2a091fc77.jpg.png
# save results/2153642330_881e250a88.jpg.png
# save results/2153642430_c8659ae417.jpg.png
# save results/2308322303_01b6ffbc15.jpg.png
# save results/2405671059_9076f89469.jpg.png
# save results/2407970586_72405c8488.jpg.png
# save results/2612657927_969e9bb275.jpg.png
# save results/2617083134_d02d5103aa.jpg.png
# save results/2688754749_35ab0c3774.jpg.png
# save results/269287644_c0262e0fc8.png
# save results/270199524_a816eac80b.png
# save results/278759049_ebfd22a71a.png
# save results/291174019_b4821c2397.png
# save results/300980715_6026e616f1.png
# save results/303058433_cbb6f763a3.png
# save results/306796477_cd48f3064c.png
# save results/314275828_94a8d70fec.png
# save results/329074102_8b41060baa.png
# save results/330211453_f55e845b84.png
# save results/447004743_fe921f2cdc.png
# save results/448871457_2b2502c248.png
# save results/450063221_09be2f43d1.png
# save results/450186182_1a8cef631d.png
# save results/457103202_ee723558ed.png
# save results/464044679_b6fbfe1535.png
# save results/473624228_11a6bc4203.png
# save results/bear and dog.png
# save results/bird01.png
# save results/bottega-e-furgone.jpg.png
# save results/boys.png
# save results/Cappuccino-2.png
# save results/Cappuccino-3.png
# save results/Cappuccino-4.png
# save results/car_cat.png
# save results/car_cat2.png
# save results/cat-2.png
# save results/cat-3.png
# save results/cat-4.png
# save results/cat-5.png
# save results/cat-6.png
# save results/cat.png
# save results/elephant2.png
# save results/fish-bike.png
# save results/Foto+Serigrafia+Furgoneta+Valencia+Inges+Kunesa.jpg.png
# save results/furgon01g.jpg.png
# save results/furgon_restos_erika_Ortiz.jpg.png
# save results/Imagen+034.jpg.png
# save results/input.png
# save results/JINJIN.png
# save results/opel-movano-furgon-lb.jpg.png
# save results/tiger-2.png
# save results/tiger-3.png
# save results/tiger.png
# save results/u%20furgone%201.JPG.png
